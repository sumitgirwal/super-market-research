# %% [markdown]
# # Super Market-Research

# %%
# %matplotlib inline

# %%
# import pandas as pd
# store=pd.read_csv("E:\\Data Science Research\\Superstore.csv")
import pandas as pd
store=pd.read_excel("E:\\Data Science Research\\Superstore.xlsx")

# %%
store.columns
# Out:
# Index(['Days to Ship Actual', 'Sales Forecast', 'Ship Status',
#        'Days to Ship Scheduled', 'Sales per Customer', 'Profit Ratio',
#        'Category', 'City', 'Country', 'Customer Name', 'Discount',
#        'Number of Records', 'Order Date', 'Order ID', 'Postal Code',
#        'Product Name', 'Profit', 'Quantity', 'Region', 'Profit per Order',
#        'Sales', 'Segment', 'Ship Date', 'Ship Mode', 'State', 'Sub-Category'],
#       dtype='object')

# %%
#store['Sales per Customer']=store['Sales per Customer'].str.replace('[$,()]','').astype(float)
#store['Profit per Order']=store['Profit per Order'].str.replace('[$,()]','').astype(float)
#store['Order Date']=pd.to_datetime(store['Order Date'])

# %%
# 59.no of customers who didn't turned again yearly basis
data=store.groupby([store['Order Date'].dt.year,store['Customer Name']])['Customer Name'].count()

# %%
# 58.how many unique customer added YOY basis
data=store.groupby([store['Order Date'].dt.year,store['Customer Name']])['Customer Name'].count()
n1=len(data[2014])
n2=len(data[2015])
n3=len(data[2016])
n4=len(data[2017])
d={
  '2015':n1-n2,
  '2016':n3-n2,
  '2017':n4-n3,
  }
ss=pd.DataFrame(d,['Customer'])
ss.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data[2014].sort_values(ascending=True).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Customer Name'>

# %%
# 55.item category-sub category wise year sales and profit
store.groupby([store['Order Date'].dt.year,store['Category'],store['Sub-Category']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='rb')
# Out:
# <AxesSubplot:xlabel='Order Date,Category,Sub-Category'>

# %%
# 54.item category-sub category wise monthly sales and profit
store.groupby([store['Order Date'].dt.month,store['Category'],store['Sub-Category']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='rb')

# %%
# 53.in a year how many orders came  on non business day 
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.day_name()]).agg({'Order ID':'count'}).plot(kind='bar',color='r')
# Out:
# <AxesSubplot:xlabel='Order Date,Order Date'>

# %%
# 52.in a year how many orders came on business day 
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.day_name()]).agg({'Order ID':'count'}).plot(kind='bar',color='r')

# %%
# 51.average sales price per order yearly -compare for all 4 yrs
store.groupby([store['Order Date'].dt.year])['Sales per Customer'].mean().plot(kind='bar',color='c')

# %%
# 50.average profit per order customer segment wise-for 4 years
store.groupby([store['Segment']])['Profit per Order'].mean().plot(kind='bar',color='y')

# %%
# 49.average profit per order month wise-for 4 years
store.groupby([store['Order Date'].dt.month,store['Segment']])['Profit per Order'].mean().plot(kind='bar',color='y')

# %%
# 48.average sales price per order customer segment wise-for 4 years
store.groupby([store['Order Date'].dt.month,store['Segment']])['Sales per Customer'].mean().plot(kind='bar',color='r')

# %%
# 47.average sales price per order month wise-for 4 years
store.groupby([store['Order Date'].dt.month])['Sales per Customer'].mean().plot(kind='bar',color='m')

# %%
# 46.top-5 customer in each customer segment order amount wise
store.groupby([store['Customer Name']])['Sales per Customer'].sum().sort_values(ascending=False).head(5).plot(kind='bar',color='r')
# Out:
# <AxesSubplot:xlabel='Customer Name'>

# %%
# 45.top-5 customer in each customer segment order amount wise
store.groupby([store['Customer Name']])['Sales per Customer'].sum().sort_values(ascending=False).head(5).plot(kind='bar',color='r')
# Out:
# <AxesSubplot:xlabel='Customer Name'>

# %%
#44.top-10 customer profit wise-yearly
store.groupby([store['Customer Name']])['Profit per Order'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='c')
# Out:
# <AxesSubplot:xlabel='Customer Name'>

# %%
# 43.top-10 customer order amount wise + no of order wise (both separte)
# ???? not solve yet!!!
store.groupby([store['Product Name']]).agg({'Sales per Customer':'sum','Order ID':'count'}).sort_values(['Sales per Customer','Order ID',],ascending=False).head(10).plot(kind='bar',color='rg')
# Out:
# <AxesSubplot:xlabel='Product Name'>

# %%
# 42.top-10 products -amount of profit wise
store.groupby([store['Product Name']])['Profit per Order'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='c')
# Out:
# <AxesSubplot:xlabel='Product Name'>

# %%
# 40.top-10 products -amount of sales wise
store.groupby([store['Product Name']])['Sales per Customer'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='c')

# %%
# 39.top-10 products -no of order wise
store.groupby([store['Product Name']])['Order ID'].count().sort_values(ascending=False).head(10).plot(kind='bar',color='c')

# %%
#38.regionwise-customer segmentwise monthly
store.groupby([store['Order Date'].dt.year,store['Region'],store['Segment']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
#37.regionwise-customer segmentwise yearly
store.groupby([store['Order Date'].dt.year,store['Region'],store['Segment']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
#36.regionwise-statewise-citywise monthly sales and profit comparision
store.groupby([store['Order Date'].dt.year,store['Region'],store['State'],store['City']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
#35.regionwise-statewise-citywise yearly sales and profit comparision
store.groupby([store['Order Date'].dt.year,store['Region'],store['State'],store['City']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
#34.regionwise-statewise monthly sales and profit comparision
store.groupby([store['Order Date'].dt.month,store['Region'],store['State']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
#33.regionwise-statewise yearly sales and profit comparision
store.groupby([store['Order Date'].dt.year,store['Region'],store['State']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
# 32.regionwise monthly sales and profit comparision
store.groupby([store['Order Date'].dt.month,store['Region']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
# 31.regionwise yearly sales and profit comparision
store.groupby([store['Order Date'].dt.year,store['Region']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
# 30.citywise monthly sales and profit comparision
store.groupby([store['Order Date'].dt.month,store['City']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='gb')

# %%
# 29.citywise yearly sales and profit comparision
store.groupby([store['Order Date'].dt.year,store['City']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='rb')

# %%
# 28.statewise monthly sales and profit comparision
store.groupby([store['Order Date'].dt.month,store['State']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='rb')

# %%
# 27.statewise yearly sales and profit comparision
store.groupby([store['Order Date'].dt.year,store['State']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='rb')

# %%
# 26.Yearwise total sales,total customer,total profit -bar chart
store.groupby([store['Order Date'].dt.year]).agg({'Sales per Customer':'sum','Profit per Order':'sum','Customer Name':'count'}).plot(kind='bar',color='rgb')

# %%
# 25.monthwise total sales,total customer,total profit -bar chart
store.groupby([store['Order Date'].dt.month]).agg({'Sales per Customer':'sum','Profit per Order':'sum','Customer Name':'count'}).plot(kind='bar',color='rgb')

# %%
# 24.yearly consumer segment percentage pie chart-per year wise
store[store.Segment=='Consumer'].groupby(store['Order Date'].dt.year)['Sales per Customer'].sum().plot.pie(subplots=True,autopct='%1i%%',shadow=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000197B0748>],
#       dtype=object)

# %%
# 23.yearly item category sales percentage pie chart-per year wise
store.groupby([store['Order Date'].dt.year,store['Category']]).agg({'Sales per Customer':'sum'}).plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D775308>],
#       dtype=object)

# %%
# 22.yearly item category sales growth comparision
store.groupby([store['Order Date'].dt.year,store['Category']]).agg({'Sales per Customer':'sum'}).plot(kind='bar',color='b',label='Consumer Wise Total Sales').legend()

# %%
# 21.month wise item category wise sales and profit
store.groupby([store['Order Date'].dt.month,store['Category']]).agg({'Sales per Customer':'sum','Profit per Order':'sum'}).plot(kind='bar',color='rm',label='Sales and Profit on Category Wise')

# %%
#20.monthwise total no of order
data=store.groupby(store['Order Date'].dt.month)['Order ID'].count().plot(kind='bar',color='c',label='Month Wise Total No of Customer').legend()

# %%
#19.yearwise total no of order
store.groupby(store['Order Date'].dt.year)['Order ID'].count().plot(kind='bar',color='c',label='Year Wise Total No of Order').legend()

# %%
#18.monthwise total no of customer
# ????? NOT SOLVED YET !!!
store.groupby(store['Order Date'].dt.month)[ab].count().plot(kind='bar',color='c',label='Year Wise Total No of Customer').legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-e8751aa67a0f> in <module>
#       1 #18.monthwise total no of customer
#       2 # ????? NOT SOLVED YET !!!
# ----> 3 store.groupby(store['Order Date'].dt.month)[ab].count().plot(kind='bar',color='c',label='Year Wise Total No of Customer').legend()
#
# NameError: name 'ab' is not defined

# %%
store[store['Customer Name']=='Chad Sievert'][['Order ID']]
# Out:
#             Order ID
# 171   CA-2014-118962
# 172   CA-2014-118962
# 173   CA-2014-118962
# 344   US-2015-120712
# 2271  CA-2015-102036
# 2691  US-2016-144211
# 2692  US-2016-144211

# %%
#17.yearwise total no of customer ERROR
# ???? NOT SOLVED YET !!!!
store.groupby([store['Order Date'].dt.year])['Customer Name'].count().plot(kind='bar',color='c',label='Year Wise Total No of Customer').legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#    1492             try:
# -> 1493                 return libindex.get_value_at(s, k)
#    1494             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-16071469d688> in <module>
#       1 #17.yearwise total no of customer ERROR
# ...

# %%
store.groupby(store['Order Date'].dt.year)['Order ID'].count().sum()
# Out:
# 9994

# %%
store.groupby(store['Order Date'].dt.year).count()
# Out:
#             Days to Ship Actual  Sales Forecast  Ship Status  \
# Order Date
# 2014                       1993            1993         1993
# 2015                       2102            2102         2102
# 2016                       2587            2587         2587
# 2017                       3312            3312         3312
#
#             Days to Ship Scheduled  Sales per Customer  Profit Ratio  \
# Order Date
# 2014                          1993                1993          1993
# 2015                          2102                2102          2102
# 2016                          2587                2587          2587
# 2017                          3312                3312          3312
#
#             Category  City  Country  Customer Name  ...  Profit  Quantity  \
# Order Date                                          ...
# 2014            1993  1993     1993           1993  ...    1993      1993
# 2015            2102  2102     2102           2102  ...    2102      2102
# ...

# %%
#16.month-wise consumer segment wise total Profit (YOY basis)
store[store.Segment=='Consumer'].groupby(store['Order Date'].dt.month)['Profit per Order'].sum().plot(kind='bar',color='b',label='Consumer Wise Total Profit Per Month').legend()

# %%
#15.month-wise consumer segment wise total Sales (YOY basis)
store[store.Segment=='Consumer'].groupby(store['Order Date'].dt.month)['Sales per Customer'].sum().plot(kind='bar',color='r',label='Consumer Wise Total Sales Per Month').legend()

# %%
# 14.consumer segment wise total profit(YOY basis)
store[store.Segment=='Consumer'].groupby(store['Order Date'].dt.year)['Profit per Order'].sum().plot(kind='bar',color='b',label='Consumer Wise Total Profit Per Year').legend()

# %%
# 13.consumer segment wise total sales(YOY basis)
store[store.Segment=='Consumer'].groupby(store['Order Date'].dt.year)['Sales per Customer'].sum().plot(kind='bar',color='g',label='Consumer Wise Total Sales').legend()

# %%
# 12.year-wise,no business-day wise total profit
# ???? NOT SOLVED YET !!!
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.day_name()]).agg({'Profit per Order':'sum'}).plot(kind='bar',color='r')

# %%
# 11.year-wise,no business-day wise total sales
# ???? NOT SOLVED YET !!!
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.day_name()]).agg({'Sales per Customer':'sum'}).plot(kind='bar',color='r')

# %%
# 10.year-wise,business-day wise total profit
# ???? NOT SOLVED YET !!!
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.day_name()]).agg({'Profit per Order':'sum'}).plot(kind='bar',color='c')

# %%
# 9.year-wise,business-day wise total sales
# ???? NOT SOLVED YET !!!
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.day_name()]).agg({'Sales per Customer':'sum'}).plot(kind='bar',color='r')

# %%
# 8.month-wise total profit(ignore year)
store.groupby([store['Order Date'].dt.month]).agg({'Profit per Order':'sum'}).plot(kind='bar',color='y')

# %%
# 7.month-wise total sales(ignore year)
store.groupby([store['Order Date'].dt.month]).agg({'Sales per Customer':'sum'}).plot(kind='bar',color='m')

# %%
#6.quarterly profit data,yearwise
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.quarter]).agg({'Profit per Order':'sum'}).plot(kind='bar',color='y')

# %%
#5.quarterly sales data,yearwise
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.quarter]).agg({'Sales per Customer':'sum'}).plot(kind='bar',color='g')

# %%
#4.year-wise,month-wise total Profit- bar and line both
# DATASET ERROR
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.month]).agg({'Profit per Order':'sum'}).plot(kind='bar',color='m')
# Out:
# <AxesSubplot:xlabel='Order Date,Order Date'>

# %%
#3.year-wise,month-wise total sales- bar and line both
store.groupby([store['Order Date'].dt.year,store['Order Date'].dt.month]).agg({'Sales per Customer':'sum'}).plot(kind='bar',color='r')
# Out:
# <AxesSubplot:xlabel='Order Date,Order Date'>

# %%
#2.year-wise total profit comparision via bar chart
store.groupby([store['Order Date'].dt.year]).agg({'Profit per Order':'sum'}).plot(kind='bar',color='c')
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
#1.year-wise total sales comparison via bar chart ,sales pct_change  graph
store.groupby([store['Order Date']]).agg({'Sales per Customer':'sum'}).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Order Date'>
